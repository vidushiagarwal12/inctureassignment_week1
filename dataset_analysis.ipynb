# %%
import pandas as pd

# %%
import numpy as np

# %%
# Replace 'students.csv' with your actual CSV file name
df = pd.read_csv(r'C:\Users\LENOVO\Downloads\adult.csv.zip')

# %%
 # Display first 5 rows

# %%
print("===== First 5 Rows of Dataset =====")
# Out:
# ===== First 5 Rows of Dataset =====

# %%
print(df.head())
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
# Display last 5 rows

# %%
print("\n===== Last 5 Rows of Dataset =====")
# Out:
# ===== Last 5 Rows of Dataset =====

# %%
print(df.tail())
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
#               occupation   relationship   race     sex  capital.gain  \
# 32556    Protective-serv  Not-in-family  White    Male             0
# 32557       Tech-support           Wife  White  Female             0
# 32558  Machine-op-inspct        Husband  White    Male             0
# 32559       Adm-clerical      Unmarried  White  Female             0
# 32560       Adm-clerical      Own-child  White    Male             0
#
#        capital.loss  hours.per.week native.country income
# ...

# %%
print("\n===== Dataset Information =====")
# Out:
# ===== Dataset Information =====

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB
# None

# %%
# Display dataset shape

# %%
print("\n===== Shape of Dataset =====")
# Out:
# ===== Shape of Dataset =====

# %%
print("Rows and Columns:", df.shape)
# Out:
# Rows and Columns: (32561, 15)

# %%
# Display column names

# %%
print("\n===== Column Names =====")
# Out:
# ===== Column Names =====

# %%
print(df.columns)
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'income'],
#       dtype='object')

# %%
# Check missing values

# %%
print("\n===== Missing Values =====")
# Out:
# ===== Missing Values =====

# %%
print(df.isnull().sum())
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
# Statistical summary

# %%
print("\n===== Statistical Summary =====")
# Out:
# ===== Statistical Summary =====

# %%
print(df.describe())
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
# Display correlation matrix

# %%
print("\n----- Correlation Matrix -----")
# Out:
# ----- Correlation Matrix -----

# %%
 print(df.corr(numeric_only=True))
# Out:
#                      age    fnlwgt  education.num  capital.gain  capital.loss  \
# age             1.000000 -0.076646       0.036527      0.077674      0.057775
# fnlwgt         -0.076646  1.000000      -0.043195      0.000432     -0.010252
# education.num   0.036527 -0.043195       1.000000      0.122630      0.079923
# capital.gain    0.077674  0.000432       0.122630      1.000000     -0.031615
# capital.loss    0.057775 -0.010252       0.079923     -0.031615      1.000000
# hours.per.week  0.068756 -0.018768       0.148123      0.078409      0.054256
#
#                 hours.per.week
# age                   0.068756
# fnlwgt               -0.018768
# education.num         0.148123
# capital.gain          0.078409
# capital.loss          0.054256
# hours.per.week        1.000000

# %%
print("\n----- Maximum Values -----")
# Out:
# ----- Maximum Values -----

# %%
print(df.max(numeric_only=True))
# Out:
# age                    90
# fnlwgt            1484705
# education.num          16
# capital.gain        99999
# capital.loss         4356
# hours.per.week         99
# dtype: int64

# %%
print("\n----- Minimum Values -----")
# Out:
# ----- Minimum Values -----

# %%
print(df.min(numeric_only=True))
# Out:
# age                  17
# fnlwgt            12285
# education.num         1
# capital.gain          0
# capital.loss          0
# hours.per.week        1
# dtype: int64

# %%
# Display Random Rows

# %%
print("\n----- Random Rows -----")
# Out:
# ----- Random Rows -----

# %%
print(df.sample(3))
# Out:
#        age workclass  fnlwgt  education  education.num      marital.status  \
# 30463   50   Private  135465  Bachelors             13  Married-civ-spouse
# 28963   38   Private   99138  Bachelors             13       Never-married
# 2005    34   Private  203488  Bachelors             13  Married-civ-spouse
#
#             occupation   relationship   race     sex  capital.gain  \
# 30463  Exec-managerial        Husband  White    Male             0
# 28963  Exec-managerial  Not-in-family  White  Female             0
# 2005             Sales        Husband  White    Male         15024
#
#        capital.loss  hours.per.week native.country income
# 30463             0              50  United-States   >50K
# 28963             0              38  United-States  <=50K
# 2005              0              40  United-States   >50K

# %%
# Sort Dataset

# %%
print("\n----- Sorted Dataset -----")
# Out:
# ----- Sorted Dataset -----

# %%
print(df.sort_values(by=df.columns[0]))
# Out:
#        age workclass  fnlwgt     education  education.num marital.status  \
# 4159    17   Private  130125          10th              6  Never-married
# 18810   17   Private  187308          10th              6  Never-married
# 25709   17   Private  153021          12th              8  Never-married
# 6046    17         ?  103810          12th              8  Never-married
# 8682    17         ?  127003           9th              5  Never-married
# ...    ...       ...     ...           ...            ...            ...
# 8791    90   Private  141758           9th              5  Never-married
# 8645    90   Private   52386  Some-college             10  Never-married
# 7756    90   Private  313986          11th              7  Never-married
# 14659   90   Private   40388     Bachelors             13  Never-married
# 0       90         ?   77053       HS-grad              9        Widowed
#
#               occupation   relationship                race     sex  \
# ...

# %%
# Display Total Number of Elements

# %%
print("\n----- Total Elements -----")
# Out:
# ----- Total Elements -----

# %%
print(df.size)
# Out:
# 488415

# %%
# Display Memory Usage

# %%
print("\n----- Memory Usage -----")
# Out:
# ----- Memory Usage -----

# %%
print(df.memory_usage())
# Out:
# Index                132
# age               260488
# workclass         260488
# fnlwgt            260488
# education         260488
# education.num     260488
# marital.status    260488
# occupation        260488
# relationship      260488
# race              260488
# sex               260488
# capital.gain      260488
# capital.loss      260488
# hours.per.week    260488
# native.country    260488
# income            260488
# dtype: int64

# %%
# Display Data Types

# %%
print("\n----- Data Types -----")
# Out:
# ----- Data Types -----

# %%
print(df.dtypes)
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education.num      int64
# marital.status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital.gain       int64
# capital.loss       int64
# hours.per.week     int64
# native.country    object
# income            object
# dtype: object

# %%
# Display Complete Dataset

# %%
print("\n----- Complete Dataset -----")
# Out:
# ----- Complete Dataset -----

# %%
print(df)
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
# Sort Dataset

# %%
print("\n----- Sorted Dataset -----")
# Out:
# ----- Sorted Dataset -----

# %%
print(df.sort_values(by=df.columns[0]))
# Out:
#        age workclass  fnlwgt     education  education.num marital.status  \
# 4159    17   Private  130125          10th              6  Never-married
# 18810   17   Private  187308          10th              6  Never-married
# 25709   17   Private  153021          12th              8  Never-married
# 6046    17         ?  103810          12th              8  Never-married
# 8682    17         ?  127003           9th              5  Never-married
# ...    ...       ...     ...           ...            ...            ...
# 8791    90   Private  141758           9th              5  Never-married
# 8645    90   Private   52386  Some-college             10  Never-married
# 7756    90   Private  313986          11th              7  Never-married
# 14659   90   Private   40388     Bachelors             13  Never-married
# 0       90         ?   77053       HS-grad              9        Widowed
#
#               occupation   relationship                race     sex  \
# ...

# %%
# Convert Age column into NumPy array

# %%
age_array = np.array(df["age"])

# %%
# Minimum age

# %%
print("\n----- MINIMUM AGE -----")
# Out:
# ----- MINIMUM AGE -----

# %%
print(np.min(age_array))
# Out:
# 17

# %%
# Maximum age

# %%
print("\n----- MAXIMUM AGE -----")
# Out:
# ----- MAXIMUM AGE -----

# %%
print(np.max(age_array))
# Out:
# 90

# %%
# Average age

# %%
print("\n----- AVERAGE AGE -----")
# Out:
# ----- AVERAGE AGE -----

# %%
print(np.mean(age_array))
# Out:
# 38.58164675532078

# %%
print("\nCSV Dataset Analysis Completed Successfully")
# Out:
# CSV Dataset Analysis Completed Successfully
